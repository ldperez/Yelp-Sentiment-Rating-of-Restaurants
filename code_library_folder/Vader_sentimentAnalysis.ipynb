# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import nltk
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import re
import string
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/datascience/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/datascience/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/datascience/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/datascience/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/datascience/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import pandas as pd
import os
import re
import nltk
import random
nltk.download('words')
nltk.download('wordnet')

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import NMF, LatentDirichletAllocation as LDA
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/datascience/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/datascience/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import praw
import os
import re
import nltk
import time
import random
import emoji
import pyLDAvis
import pyLDAvis.sklearn
import pyLDAvis.gensim_models
import warnings
warnings.filterwarnings("ignore")

from spacy.lang.en.stop_words import STOP_WORDS as stopwords
from string import punctuation

from collections import Counter, defaultdict
from wordcloud import WordCloud
from sklearn.decomposition import NMF, TruncatedSVD, LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from spacy.lang.en.stop_words import STOP_WORDS as stopwords
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords 
nltk.download('stopwords')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/datascience/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv('/Users/datascience/Desktop/Cap/pre_processed.csv')
df
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 2       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 3       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 4       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# ...                        ...                       ...
# 348851  JhSByBTYY1rGstRy76YmLA         Reiki with Darren
# 348852  JhSByBTYY1rGstRy76YmLA         Reiki with Darren
# 348853  JhSByBTYY1rGstRy76YmLA         Reiki with Darren
# 348854  JhSByBTYY1rGstRy76YmLA         Reiki with Darren
# 348855  JhSByBTYY1rGstRy76YmLA         Reiki with Darren
#
#                        address           city state  postal_code   latitude  \
# 0       1616 Chapala St, Ste 2  Santa Barbara    CA      93101.0  34.426679
# 1       1616 Chapala St, Ste 2  Santa Barbara    CA      93101.0  34.426679
# 2       1616 Chapala St, Ste 2  Santa Barbara    CA      93101.0  34.426679
# 3       1616 Chapala St, Ste 2  Santa Barbara    CA      93101.0  34.426679
# 4       1616 Chapala St, Ste 2  Santa Barbara    CA      93101.0  34.426679
# ...                        ...            ...   ...          ...        ...
# 348851                     NaN  Santa Barbara    CA      93105.0  34.420831
# 348852                     NaN  Santa Barbara    CA      93105.0  34.420831
# 348853                     NaN  Santa Barbara    CA      93105.0  34.420831
# 348854                     NaN  Santa Barbara    CA      93105.0  34.420831
# 348855                     NaN  Santa Barbara    CA      93105.0  34.420831
#
#          longitude  stars_x  review_count  ...  stars_y useful funny cool  \
# 0      -119.711197      5.0             7  ...        5      3     2    1
# 1      -119.711197      5.0             7  ...        5      1     0    0
# 2      -119.711197      5.0             7  ...        4      2     0    0
# 3      -119.711197      5.0             7  ...        5      0     1    0
# 4      -119.711197      5.0             7  ...        5      0     0    0
# ...            ...      ...           ...  ...      ...    ...   ...  ...
# 348851 -119.698190      5.0             7  ...        5      0     0    1
# 348852 -119.698190      5.0             7  ...        5      0     0    0
# 348853 -119.698190      5.0             7  ...        5      0     0    0
# 348854 -119.698190      5.0             7  ...        5      0     0    1
# 348855 -119.698190      5.0             7  ...        5      0     0    0
#
#                                                      text  \
# 0       I've had acupuncture treatments with Abby over...
# 1       Abby is an amazing practitioner. In a treatmen...
# 2       I went to see Abby for some digestive issues. ...
# 3       Abby helped me with some longstanding issues, ...
# 4       Recently, I referred a patient of mine with mu...
# ...                                                   ...
# 348851  I was new to Reiki when I first met Darren and...
# 348852  Darren is a trusting, experienced professional...
# 348853  Darren is always welcoming and sooo nice. He m...
# 348854  I've already sang Darren's praises to my frien...
# 348855  I Had a wonderful Reiki session . He is very p...
#
#                        date  \
# 0       2012-05-02 18:07:38
# 1       2013-03-01 06:11:05
# 2       2013-01-17 00:05:43
# 3       2015-03-16 03:43:08
# 4       2013-03-05 18:45:07
# ...                     ...
# 348851  2018-04-07 08:09:58
# 348852  2018-08-07 02:01:15
# 348853  2018-08-31 02:02:25
# 348854  2018-04-13 03:20:45
# 348855  2018-04-01 18:08:30
#
#                                            text_processed  \
# 0       have acupuncture treatment with abby over the ...
# 1       abby be an amazing practitioner in a treatment...
# 2       I go to see abby for some digestive issue I be...
# 3       abby help I with some longstanding issue inclu...
# 4       recently I refer a patient of mine with multip...
# ...                                                   ...
# 348851  I be new to reiki when I first meet darren and...
# 348852  darren be a trusting experience professional h...
# 348853  darren be always welcome and sooo nice he make...
# 348854  already sing praise to my friend and it have b...
# 348855  I have a wonderful reiki session he be very pr...
#
#                                                    tokens  num_tokens  \
# 0       ['ive', 'acupuncture', 'treatment', 'abby', 'p...          56
# 1       ['abby', 'amazing', 'practitioner', 'treatment...          39
# 2       ['went', 'see', 'abby', 'digestive', 'issue', ...          69
# 3       ['abby', 'helped', 'longstanding', 'issue', 'i...          46
# 4       ['recently', 'referred', 'patient', 'mine', 'm...          23
# ...                                                   ...         ...
# 348851  ['new', 'reiki', 'first', 'met', 'darren', 'wo...          29
# 348852  ['darren', 'trusting', 'experienced', 'profess...          41
# 348853  ['darren', 'always', 'welcoming', 'sooo', 'nic...          25
# 348854  ['ive', 'already', 'sang', 'darrens', 'praise'...          34
# 348855  ['wonderful', 'reiki', 'session', 'professiona...           8
#
#         has_emoji
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 348851      False
# 348852      False
# 348853      False
# 348854      False
# 348855      False
#
# [348856 rows x 26 columns]

# %%
# Drop rows with NaN values in categories column
df = df.dropna(subset=['categories'])

# Keep only rows where categories contain 'restaurants' or 'food'
df = df[df['categories'].str.contains('restaurants|food', case=False, regex=True)]

# Get the length of the resulting dataframe
length = len(df)

print(f"Length of dataset: {length}")
# Out:
# Length of dataset: 239065

# %%
df = df.rename(columns={'text_processed': 'review', 'name': 'location'})

df
# Out:
#                    business_id              location                address  \
# 31      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 32      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 33      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 34      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 35      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# ...                        ...                   ...                    ...
# 348844  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 348845  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 348846  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 348847  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 348848  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
#
#                  city state  postal_code   latitude   longitude  stars_x  \
# 31      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 32      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 33      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 34      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 35      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# ...               ...   ...          ...        ...         ...      ...
# 348844  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 348845  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 348846  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 348847  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 348848  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
#
#         review_count  ...  stars_y useful funny cool  \
# 31               389  ...        5      0     0    0
# 32               389  ...        5      0     0    0
# 33               389  ...        4      0     0    0
# 34               389  ...        5      0     1    1
# 35               389  ...        2      3     0    0
# ...              ...  ...      ...    ...   ...  ...
# 348844           299  ...        5      0     0    0
# 348845           299  ...        4      0     0    0
# 348846           299  ...        1      1     1    0
# 348847           299  ...        5      3     0    1
# 348848           299  ...        5      0     0    0
#
#                                                      text  \
# 31      What a great addition to the Funk Zone!  Grab ...
# 32      Possibly the best breakfast sandwich EVER.  On...
# 33      Pricey ( a ham and cheese croissant was $5.50)...
# 34      Are you kidding me? This is without a doubt so...
# 35      Super slow service, "salads" are not very good...
# ...                                                   ...
# 348844  This is one of my new favorite pizza joints he...
# 348845  Ordered vegan chicken and Daiya cheese and onl...
# 348846  This was the worst pizza I've ever had ever ea...
# 348847  One of the best pizzas in SB....seriously!!!\n...
# 348848  We wanted a calzone and it was getting around ...
#
#                        date  \
# 31      2016-10-13 22:50:47
# 32      2017-01-15 00:36:04
# 33      2018-07-17 00:20:41
# 34      2018-01-09 20:44:47
# 35      2017-02-09 19:09:31
# ...                     ...
# 348844  2015-04-11 04:43:19
# 348845  2015-05-26 15:27:36
# 348846  2019-07-08 19:27:04
# 348847  2014-07-07 18:40:39
# 348848  2016-11-06 05:15:44
#
#                                                    review  \
# 31      what a great addition to the funk zone grab a ...
# 32      possibly the good breakfast sandwich ever on a...
# 33      pricey a ham and cheese croissant be as with a...
# 34      be you kid I this be without a doubt some of t...
# 35      super slow service be not very good and really...
# ...                                                   ...
# 348844  this be one of my new favorite pizza joint her...
# 348845  order vegan chicken and daiya cheese and only ...
# 348846  this be the bad pizza ever have ever eatenwe o...
# 348847  one of the good pizza in sbseriouslythis be a ...
# 348848  we want a calzone and it be get around the tim...
#
#                                                    tokens  num_tokens  \
# 31      ['great', 'addition', 'funk', 'zone', 'grab', ...          24
# 32      ['possibly', 'best', 'breakfast', 'sandwich', ...           9
# 33      ['pricey', 'ham', 'cheese', 'croissant', '550'...          46
# 34      ['kidding', 'without', 'doubt', 'best', 'food'...          30
# 35      ['super', 'slow', 'service', 'salad', 'good', ...           9
# ...                                                   ...         ...
# 348844  ['one', 'new', 'favorite', 'pizza', 'joint', '...          69
# 348845  ['ordered', 'vegan', 'chicken', 'daiya', 'chee...          36
# 348846  ['worst', 'pizza', 'ive', 'ever', 'ever', 'eat...          51
# 348847  ['one', 'best', 'pizza', 'sbseriously', 'regul...         116
# 348848  ['wanted', 'calzone', 'getting', 'around', 'ti...          31
#
#         has_emoji
# 31          False
# 32          False
# 33          False
# 34          False
# 35          False
# ...           ...
# 348844      False
# 348845      False
# 348846      False
# 348847      False
# 348848      False
#
# [239065 rows x 26 columns]

# %%
df['review'] = df['review'].astype(str)

# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sid = SentimentIntensityAnalyzer()

# %%
import re
import nltk

def split_into_phrases(text):
    sentences = nltk.sent_tokenize(text)
    phrases = []
    for sentence in sentences:
        tokens = nltk.word_tokenize(sentence)
        # split sentence into phrases based on conjunctions, punctuation, and other rules
        conjunctions = ["for", "and", "nor", "but", "or", "yet", "so", "although", "though", "even though", "while", "if", "unless", "until", "since", "because", "as", "in order that", "so that", "that", "whether", "while", "who", "whom", "whose", "which", "what", "where", "when", "why", "how", "therefore", "furthermore", "however", "nevertheless", "moreover", "in addition", "on the other hand", "in contrast", "meanwhile", "conversely", "likewise", "nonetheless", "regardless", "thus", "to conclude", "to summarize", "in conclusion", "in summary", "to sum up", "to put it differently", "that is to say", "in other words", "for example", "such as", "including", "namely", "particularly", "notably", "chiefly", "mostly", "mainly", "primarily", "not only", "but also", "besides", "even", "indeed", "in fact", "to be sure", "above all", "certainly", "in any case", "in essence", "in particular", "in short", "in brief", "to this end", "with this in mind", "to begin with", "firstly", "secondly", "thirdly", "lastly", "finally", "meanwhile", "accordingly", "consequently", "hence", "otherwise", "thus", "thereby", "therefore", "whereas", "all in all", "altogether", "as a result", "at any rate", "in any event", "in brief", "in conclusion", "on balance", "on the whole", "to sum up", "to summarize", "after all", "as has been noted", "in a word", "in brief", "in conclusion", "in essence", "in summary", "on balance", "to conclude", "to sum up", "to summarize"]
        phrase = ""
        for i, token in enumerate(tokens):
            if token in conjunctions or token in ".,;:":
                phrases.append(phrase.strip())
                phrase = ""
            elif i > 0 and re.match(r"^[A-Z]{1}[a-z]+$", token) and re.match(r"^[a-z]+$", tokens[i-1]):
                phrases.append(phrase.strip())
                phrase = token
            elif i > 0 and token == "'" and tokens[i-1].endswith("s"):
                phrase += tokens[i-1]
            else:
                phrase += " " + token
        if phrase:
            phrases.append(phrase.strip())
    return phrases

# %%
df['phrases'] = df['review'].apply(lambda x: split_into_phrases(x))
df
# Out:
#                    business_id              location                address  \
# 31      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 32      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 33      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 34      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 35      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# ...                        ...                   ...                    ...
# 348844  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 348845  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 348846  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 348847  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 348848  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
#
#                  city state  postal_code   latitude   longitude  stars_x  \
# 31      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 32      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 33      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 34      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 35      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# ...               ...   ...          ...        ...         ...      ...
# 348844  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 348845  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 348846  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 348847  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 348848  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
#
#         review_count  ...  useful funny cool  \
# 31               389  ...       0     0    0
# 32               389  ...       0     0    0
# 33               389  ...       0     0    0
# 34               389  ...       0     1    1
# 35               389  ...       3     0    0
# ...              ...  ...     ...   ...  ...
# 348844           299  ...       0     0    0
# 348845           299  ...       0     0    0
# 348846           299  ...       1     1    0
# 348847           299  ...       3     0    1
# 348848           299  ...       0     0    0
#
#                                                      text  \
# 31      What a great addition to the Funk Zone!  Grab ...
# 32      Possibly the best breakfast sandwich EVER.  On...
# 33      Pricey ( a ham and cheese croissant was $5.50)...
# 34      Are you kidding me? This is without a doubt so...
# 35      Super slow service, "salads" are not very good...
# ...                                                   ...
# 348844  This is one of my new favorite pizza joints he...
# 348845  Ordered vegan chicken and Daiya cheese and onl...
# 348846  This was the worst pizza I've ever had ever ea...
# 348847  One of the best pizzas in SB....seriously!!!\n...
# 348848  We wanted a calzone and it was getting around ...
#
#                        date  \
# 31      2016-10-13 22:50:47
# 32      2017-01-15 00:36:04
# 33      2018-07-17 00:20:41
# 34      2018-01-09 20:44:47
# 35      2017-02-09 19:09:31
# ...                     ...
# 348844  2015-04-11 04:43:19
# 348845  2015-05-26 15:27:36
# 348846  2019-07-08 19:27:04
# 348847  2014-07-07 18:40:39
# 348848  2016-11-06 05:15:44
#
#                                                    review  \
# 31      what a great addition to the funk zone grab a ...
# 32      possibly the good breakfast sandwich ever on a...
# 33      pricey a ham and cheese croissant be as with a...
# 34      be you kid I this be without a doubt some of t...
# 35      super slow service be not very good and really...
# ...                                                   ...
# 348844  this be one of my new favorite pizza joint her...
# 348845  order vegan chicken and daiya cheese and only ...
# 348846  this be the bad pizza ever have ever eatenwe o...
# 348847  one of the good pizza in sbseriouslythis be a ...
# 348848  we want a calzone and it be get around the tim...
#
#                                                    tokens  num_tokens  \
# 31      ['great', 'addition', 'funk', 'zone', 'grab', ...          24
# 32      ['possibly', 'best', 'breakfast', 'sandwich', ...           9
# 33      ['pricey', 'ham', 'cheese', 'croissant', '550'...          46
# 34      ['kidding', 'without', 'doubt', 'best', 'food'...          30
# 35      ['super', 'slow', 'service', 'salad', 'good', ...           9
# ...                                                   ...         ...
# 348844  ['one', 'new', 'favorite', 'pizza', 'joint', '...          69
# 348845  ['ordered', 'vegan', 'chicken', 'daiya', 'chee...          36
# 348846  ['worst', 'pizza', 'ive', 'ever', 'ever', 'eat...          51
# 348847  ['one', 'best', 'pizza', 'sbseriously', 'regul...         116
# 348848  ['wanted', 'calzone', 'getting', 'around', 'ti...          31
#
#         has_emoji                                            phrases
# 31          False  [, a great addition to the funk zone grab a bi...
# 32          False  [possibly the good breakfast sandwich ever on ...
# 33          False  [pricey a ham, cheese croissant be, with anywh...
# 34          False  [be you kid I this be without a doubt some of ...
# 35          False  [super slow service be not very good, really o...
# ...           ...                                                ...
# 348844      False  [this be one of my new favorite pizza joint he...
# 348845      False  [order vegan chicken, daiya cheese, only wait,...
# 348846      False  [this be the bad pizza ever have ever eatenwe ...
# 348847      False  [one of the good pizza in sbseriouslythis be a...
# 348848      False  [we want a calzone, it be get around the time,...
#
# [239065 rows x 27 columns]

# %%
def filter_phrases_with_keywords(phrases, aspect_keywords):
    filtered_phrases = []
    deleted_phrases = []
    for phrase in phrases:
        aspect_found = False
        for aspect, keywords in aspect_keywords.items():
            if any(keyword.lower() in phrase.lower() for keyword in keywords):
                filtered_phrases.append(phrase)
                aspect_found = True
                break
        if not aspect_found:
            deleted_phrases.append(phrase)
    return filtered_phrases, deleted_phrases

# %%
with open('categories.txt', 'r') as file:
    contents = file.read()
aspect_keywords_dict = eval(contents)

# %%
aspect_keywords =aspect_keywords_dict

# %%
df
# Out:
#                    business_id              location                address  \
# 31      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 32      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 33      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 34      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 35      IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# ...                        ...                   ...                    ...
# 348844  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 348845  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 348846  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 348847  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 348848  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
#
#                  city state  postal_code   latitude   longitude  stars_x  \
# 31      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 32      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 33      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 34      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 35      Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# ...               ...   ...          ...        ...         ...      ...
# 348844  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 348845  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 348846  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 348847  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 348848  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
#
#         review_count  ...  useful funny cool  \
# 31               389  ...       0     0    0
# 32               389  ...       0     0    0
# 33               389  ...       0     0    0
# 34               389  ...       0     1    1
# 35               389  ...       3     0    0
# ...              ...  ...     ...   ...  ...
# 348844           299  ...       0     0    0
# 348845           299  ...       0     0    0
# 348846           299  ...       1     1    0
# 348847           299  ...       3     0    1
# 348848           299  ...       0     0    0
#
#                                                      text  \
# 31      What a great addition to the Funk Zone!  Grab ...
# 32      Possibly the best breakfast sandwich EVER.  On...
# 33      Pricey ( a ham and cheese croissant was $5.50)...
# 34      Are you kidding me? This is without a doubt so...
# 35      Super slow service, "salads" are not very good...
# ...                                                   ...
# 348844  This is one of my new favorite pizza joints he...
# 348845  Ordered vegan chicken and Daiya cheese and onl...
# 348846  This was the worst pizza I've ever had ever ea...
# 348847  One of the best pizzas in SB....seriously!!!\n...
# 348848  We wanted a calzone and it was getting around ...
#
#                        date  \
# 31      2016-10-13 22:50:47
# 32      2017-01-15 00:36:04
# 33      2018-07-17 00:20:41
# 34      2018-01-09 20:44:47
# 35      2017-02-09 19:09:31
# ...                     ...
# 348844  2015-04-11 04:43:19
# 348845  2015-05-26 15:27:36
# 348846  2019-07-08 19:27:04
# 348847  2014-07-07 18:40:39
# 348848  2016-11-06 05:15:44
#
#                                                    review  \
# 31      what a great addition to the funk zone grab a ...
# 32      possibly the good breakfast sandwich ever on a...
# 33      pricey a ham and cheese croissant be as with a...
# 34      be you kid I this be without a doubt some of t...
# 35      super slow service be not very good and really...
# ...                                                   ...
# 348844  this be one of my new favorite pizza joint her...
# 348845  order vegan chicken and daiya cheese and only ...
# 348846  this be the bad pizza ever have ever eatenwe o...
# 348847  one of the good pizza in sbseriouslythis be a ...
# 348848  we want a calzone and it be get around the tim...
#
#                                                    tokens  num_tokens  \
# 31      ['great', 'addition', 'funk', 'zone', 'grab', ...          24
# 32      ['possibly', 'best', 'breakfast', 'sandwich', ...           9
# 33      ['pricey', 'ham', 'cheese', 'croissant', '550'...          46
# 34      ['kidding', 'without', 'doubt', 'best', 'food'...          30
# 35      ['super', 'slow', 'service', 'salad', 'good', ...           9
# ...                                                   ...         ...
# 348844  ['one', 'new', 'favorite', 'pizza', 'joint', '...          69
# 348845  ['ordered', 'vegan', 'chicken', 'daiya', 'chee...          36
# 348846  ['worst', 'pizza', 'ive', 'ever', 'ever', 'eat...          51
# 348847  ['one', 'best', 'pizza', 'sbseriously', 'regul...         116
# 348848  ['wanted', 'calzone', 'getting', 'around', 'ti...          31
#
#         has_emoji                                            phrases
# 31          False  [, a great addition to the funk zone grab a bi...
# 32          False  [possibly the good breakfast sandwich ever on ...
# 33          False  [pricey a ham, cheese croissant be, with anywh...
# 34          False  [be you kid I this be without a doubt some of ...
# 35          False  [super slow service be not very good, really o...
# ...           ...                                                ...
# 348844      False  [this be one of my new favorite pizza joint he...
# 348845      False  [order vegan chicken, daiya cheese, only wait,...
# 348846      False  [this be the bad pizza ever have ever eatenwe ...
# 348847      False  [one of the good pizza in sbseriouslythis be a...
# 348848      False  [we want a calzone, it be get around the time,...
#
# [239065 rows x 27 columns]

# %%
from collections import defaultdict

def create_aspect_columns(df, aspect_keywords):
    aspect_dict = defaultdict(list)
    
    for aspect, keywords in aspect_keywords.items():
        for keyword in keywords:
            aspect_dict[keyword.lower()].append(aspect)

    for aspect in aspect_keywords.keys():
        df[aspect] = ''
    
    for i in range(len(df)):
        for phrase in df.loc[i, 'phrases']:
            for word in phrase.split():
                word = word.lower()
                if word in aspect_dict:
                    for aspect in aspect_dict[word]:
                        df.at[i, aspect] = phrase
                    break
                    
    return df

# %%
df = df.reset_index(drop=True)

df = create_aspect_columns(df, aspect_keywords)
df
# Out:
#                    business_id              location                address  \
# 0       IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 1       IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 2       IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 3       IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 4       IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# ...                        ...                   ...                    ...
# 239060  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 239061  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 239062  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 239063  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
# 239064  uriD7RFuHhLJeDdKaf0nFA            Pizza Guru          3534 State St
#
#                  city state  postal_code   latitude   longitude  stars_x  \
# 0       Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 1       Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 2       Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 3       Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# 4       Santa Barbara    CA      93101.0  34.414445 -119.690672      4.0
# ...               ...   ...          ...        ...         ...      ...
# 239060  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 239061  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 239062  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 239063  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
# 239064  Santa Barbara    CA      93105.0  34.440689 -119.739681      4.0
#
#         review_count  ...                                             tokens  \
# 0                389  ...  ['great', 'addition', 'funk', 'zone', 'grab', ...
# 1                389  ...  ['possibly', 'best', 'breakfast', 'sandwich', ...
# 2                389  ...  ['pricey', 'ham', 'cheese', 'croissant', '550'...
# 3                389  ...  ['kidding', 'without', 'doubt', 'best', 'food'...
# 4                389  ...  ['super', 'slow', 'service', 'salad', 'good', ...
# ...              ...  ...                                                ...
# 239060           299  ...  ['one', 'new', 'favorite', 'pizza', 'joint', '...
# 239061           299  ...  ['ordered', 'vegan', 'chicken', 'daiya', 'chee...
# 239062           299  ...  ['worst', 'pizza', 'ive', 'ever', 'ever', 'eat...
# 239063           299  ...  ['one', 'best', 'pizza', 'sbseriously', 'regul...
# 239064           299  ...  ['wanted', 'calzone', 'getting', 'around', 'ti...
#
#        num_tokens has_emoji  \
# 0              24     False
# 1               9     False
# 2              46     False
# 3              30     False
# 4               9     False
# ...           ...       ...
# 239060         69     False
# 239061         36     False
# 239062         51     False
# 239063        116     False
# 239064         31     False
#
#                                                   phrases  \
# 0       [, a great addition to the funk zone grab a bi...
# 1       [possibly the good breakfast sandwich ever on ...
# 2       [pricey a ham, cheese croissant be, with anywh...
# 3       [be you kid I this be without a doubt some of ...
# 4       [super slow service be not very good, really o...
# ...                                                   ...
# 239060  [this be one of my new favorite pizza joint he...
# 239061  [order vegan chicken, daiya cheese, only wait,...
# 239062  [this be the bad pizza ever have ever eatenwe ...
# 239063  [one of the good pizza in sbseriouslythis be a...
# 239064  [we want a calzone, it be get around the time,...
#
#                                                      food  \
# 0       a great addition to the funk zone grab a bite ...
# 1       possibly the good breakfast sandwich ever on a...
# 2                       pesto sammy be also great go back
# 3                                  kind coffee look great
# 4
# ...                                                   ...
# 239060  the crust come out the same on their whole piz...
# 239061  min to get this freshly bake pizza the crust b...
# 239062                    a greasy mess the crust be thin
# 239063          the buffalo chicken each be pretty unique
# 239064   greek salad both be awesome we split the calzone
#
#                                                   service  \
# 0
# 1
# 2
# 3
# 4                     super slow service be not very good
# ...                                                   ...
# 239060  both be great I have only order their pizza by...
# 239061  satisfying service be excellent the waiter let...
# 239062
# 239063  you can manage to order during happy hour thin...
# 239064
#
#                                        price  \
# 0
# 1
# 2                               pricey a ham
# 3       I try it I will be price be good too
# 4                really over price be return
# ...                                      ...
# 239060
# 239061
# 239062
# 239063     entertainment purpose price cheap
# 239064
#
#                                           atmosphere  \
# 0
# 1
# 2
# 3                       very chic people be friendly
# 4
# ...                                              ...
# 239060
# 239061    friend gather hope to come back again soon
# 239062  my family with a hot car full of sick people
# 239063                            we can watch sport
# 239064
#
#                                          alternative diet  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 239060
# 239061
# 239062
# 239063  plus it just plain taste good they also have g...
# 239064  it be more of a healthy place we get a large h...
#
#                                          locationCategory
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 239060  the first time about a month ago I live in lon...
# 239061
# 239062
# 239063
# 239064
#
# [239065 rows x 33 columns]

# %% [markdown]
# ### Vader

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

def get_sentiment_score(text):
    sia = SentimentIntensityAnalyzer()
    sentiment_dict = sia.polarity_scores(text)
    return sentiment_dict['compound']

# %%
df['food_sentiment'] = df['food'].apply(get_sentiment_score)

# %%
df['service_sentiment'] = df['service'].apply(get_sentiment_score)

# %%
df['atmosphere_sentiment'] = df['atmosphere'].apply(get_sentiment_score)

# %%
df['price_sentiment'] = df['price'].apply(get_sentiment_score)

# %%
df['alternative_diet_sentiment'] = df['alternative diet'].apply(get_sentiment_score)

# %%
df['locationCategory_sentiment'] = df['locationCategory'].apply(get_sentiment_score)

# %%
# assume `df` is the pandas dataframe you want to output
file_path = "/Users/datascience/Desktop/Cap/all.csv"
df.to_csv(file_path, index=False)

# %% [markdown]
# Total

# %%
# Group by location and calculate the average sentiment score for each aspect keyword
grouped_df = df.groupby('location').mean().reset_index()

# Select only the location and aspect sentiment columns
location_sentiment_df = grouped_df[['location'] + [col for col in grouped_df.columns if '_sentiment' in col]]

# Print the result
location_sentiment_df
# Out:
#                      location  food_sentiment  service_sentiment  \
# 0                    101 Deli        0.388964           0.126314
# 1     1114 Sports Bar & Games        0.292677           0.185226
# 2                 212° Hotpot        0.215999           0.124466
# 3              4 Eggs & Pizza        0.368523           0.028793
# 4       6831 AA Hollister Ave        0.134724           0.043982
# ...                       ...             ...                ...
# 1388               duo events        0.336792           0.227058
# 1389                 goa taco        0.284901           0.068132
# 1390        iGrill Korean BBQ        0.193814           0.094343
# 1391               il Fustino        0.145207           0.175782
# 1392               il fustino        0.139333           0.113467
#
#       atmosphere_sentiment  price_sentiment  alternative_diet_sentiment  \
# 0                 0.047654         0.139221                    0.000000
# 1                 0.220003         0.065612                    0.010899
# 2                 0.186247         0.075331                    0.009335
# 3                 0.137774         0.003134                    0.019121
# 4                 0.090606        -0.045112                    0.000000
# ...                    ...              ...                         ...
# 1388              0.066983         0.000000                    0.000000
# 1389              0.078556         0.056225                    0.033227
# 1390              0.100181         0.082688                    0.006602
# 1391              0.196071         0.206607                    0.014354
# 1392              0.171133         0.000000                    0.000000
#
#       locationCategory_sentiment
# 0                       0.013971
# 1                       0.053947
# 2                       0.020612
# 3                       0.011843
# 4                       0.035594
# ...                          ...
# 1388                    0.000000
# 1389                    0.016171
# 1390                   -0.005718
# 1391                    0.029200
# 1392                    0.104150
#
# [1393 rows x 7 columns]

# %%
# output DF to a csv
# assume `df` is the pandas dataframe you want to output
file_path = "/Users/datascience/Desktop/Cap/pivot.csv"
location_sentiment_df.to_csv(file_path, index=False)
